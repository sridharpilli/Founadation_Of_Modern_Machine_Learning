# %% [markdown]
# <a href="https://colab.research.google.com/github/sridharpilli/Founadation_Of_Modern_Machine_Learning/blob/main/FMML_Mod8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-03 15:03:32--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   386MB/s    in 0.2s
#
# 2023-05-03 15:03:36 (386 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 20876  1704.05325v1  The advent of the Big Data hype and the consis...    cs
# 10663   1206.6385v1  Locally adapted parameterizations of a model (...    cs
# 36794   1412.0691v2  In this paper we introduce a knowledge engine,...    cs
# 7456   1801.01061v1  We propose a class of intrinsic Gaussian proce...  stat
# 20527  1606.00626v3  Detection of non-technical losses (NTL) which ...    cs
# ...             ...                                                ...   ...
# 6338   1611.04967v1  Predictive models are increasingly deployed fo...    cs
# 9352    1312.3613v2  It is time-consuming and error-prone to implem...  stat
# 16970  1707.07086v1  We propose a new, socially-impactful task for ...    cs
# 37128  1608.02193v4  Using the previously developed concepts of sem...    cs
# 13803  1506.02361v1  The spike trains are the main components of th...    cs
#
#                                                    title  year  \
# 20876  Anomaly detection and motif discovery in symbo...  2017
# 10663         Improved Estimation in Time Varying Models  2012
# 36794  RoboBrain: Large-Scale Knowledge Engine for Ro...  2014
# 7456   Intrinsic Gaussian processes on complex constr...  2018
# 20527  The Challenge of Non-Technical Loss Detection ...  2016
# ...                                                  ...   ...
# 6338   Iterative Orthogonal Feature Projection for Di...  2016
# 9352   Augur: a Modeling Language for Data-Parallel P...  2013
# 16970  Identifying civilians killed by police with di...  2017
# 37128  Spacetimes with Semantics (III) - The Structur...  2016
# 13803  Microscopic approach of a time elapsed neural ...  2015
#
#                                                 keywords
# 20876  [consistent, recollection, monitoring, configu...
# 10663  [parameterizations, expressive, estimating, si...
# 36794  [introduce, knowledge, knowledge, representati...
# 7456   [intrinsic, processes, interpolation, regressi...
# 20527  [detection, technical, electricity, attracted,...
# ...                                                  ...
# 6338   [predictive, increasingly, determining, insura...
# 9352   [consuming, implement, inference, procedures, ...
# 16970  [impactful, processing, collected, supervision...
# 37128  [previously, developed, spacetime, interpretat...
# 13803  [components, information, processing, processe...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 20876    [consistent, recollection, monitoring, configu...
# 10663    [parameterizations, expressive, estimating, si...
# 36794    [introduce, knowledge, knowledge, representati...
# 7456     [intrinsic, processes, interpolation, regressi...
# 20527    [detection, technical, electricity, attracted,...
#                                ...
# 37849    [penalized, orthogonal, components, regression...
# 11469    [information, numerical, measurements, informa...
# 12985    [homogeneous, subgroups, biomedical, applicati...
# 23244    [classification, character, recognition, signi...
# 6659     [important, inference, challenges, including, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8897 words.
# Out of those 4599 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3320bafd-84c6-45bb-acef-4f00078234d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3320bafd-84c6-45bb-acef-4f00078234d8")) {                    Plotly.newPlot(                        "3320bafd-84c6-45bb-acef-4f00078234d8",                        [{"x":["approximation","scenarios","accomplished","benchmark","aggregate","configuration","representations","monitoring","consistent","generated","processing","discovery","algorithms","representation","detection","representing","archetypal","synthetic","estimation","algorithm","classification","parameterizations","formulation","illustrate","important","simultaneously","structure","estimating","constitutes","approximating","extension","transformed","expressive","empirical","demonstrate","information","trajectories","including","different","challenge","formulating","challenges","knowledge","correctness","collaborative","grounding","introduce","inferring","interactions","modalities","technical","associated","mechanisms","perception","performing","architecture","interpolation","euclidean","constrained","approaches","processes","transition","constructing","relationship","regression","simulation","illustrated","practically","covariance","manifolds","conditions","generality","potentially","utilities","computationally","intrinsic","irregular","accommodate","smoothing","distributed","attracted","identifies","attention","engineering","direction","electrical","countries","researchers","scientific","artificial","increasing","employing","stability","intelligence","comprehensive","electricity","providers","addressed","significant","reliability","predominant","ubiquitous","converting","corresponds","additional","conceptually","situation","discriminating","relevance","unlabeled","identified","automatically","supervised","retrieval","subsamples","applications","particular","transductive","inductive","empirically","simulated","available","classifier","recurrent","stabilisation","detecting","efficient","properties","stochastic","instability","signature","depressive","disability","prospective","technological","substantial","reporting","identification","combination","depression","performance","appropriate","consideration","intelligent","evaluating","comparison","probability","application","relational","structures","effective","magnitude","inference","reasoning","resulting","experiments","regarding","technique","compilation","questions","efficiently","techniques","compiling","backpropagation","competitive","decoupled","reasonably","optimizing","introduced","traditional","demonstrating","applicability","resolution","multilayer","equivalent","improvements","unsupervised","advantage","supervision","reproducing","prediction","convolutional","proposing","characterize","projections","maintains","differing","dimension","visualize","expression","dimensional","determined","exploited","determining","preserving","fluorescent","exploratory","relationships","selection","projection"],"y":[103,88,15,206,25,24,238,46,80,191,299,60,615,376,325,71,2,137,217,854,483,1,80,70,338,111,355,65,11,18,84,25,28,144,581,679,36,259,750,147,7,116,330,11,34,11,327,23,87,35,38,103,49,39,72,254,10,22,61,437,101,41,42,71,131,92,16,16,20,14,132,10,38,6,83,43,9,10,28,106,27,23,163,54,73,9,8,77,37,143,102,42,41,88,52,4,9,34,211,28,3,13,6,22,111,7,37,11,35,38,33,189,177,125,1,455,232,3,18,87,65,299,131,147,0,76,419,203,134,11,12,0,1,0,7,41,12,99,125,1,891,73,31,72,51,135,184,266,24,139,249,64,195,109,152,597,30,263,5,49,168,370,4,19,98,4,7,46,132,171,25,36,112,15,56,106,124,82,48,11,235,362,30,55,16,12,5,69,9,55,196,52,25,40,50,1,9,75,136,39],"type":"bar"},{"x":["approximation","scenarios","accomplished","benchmark","aggregate","configuration","repr ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4599,), (4599, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8075

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Textual</span> <span style='background-color:rgba(0, 255, 0, 0.4999999999999999);'>Entailment</span> <span style='background-color:rgba(0, 255, 0, 0.7837837837837838);'>Recognizing</span> <span style=''>by</span> <span style=''>Theorem</span> <span style=''>Proving</span> <span style=''>Approach</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>two</span> <span style=''>original</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.7837837837837838);'>recognizing</span> <span style=''>textual</span> <span style='background-color:rgba(255, 0, 0, 0.3264248704663213);'>inference</span> <span style=''>First</span> <span style=''>one</span> <span style=''>is</span> <span style=''>a</span> <span style=''>modified</span> <span style='background-color:rgba(0, 255, 0, 0.6115107913669064);'>resolution</span> <span style=''>method</span> <span style=''>such</span> <span style=''>that</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.9210526315789473);'>linguistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considerations</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>unification</span> <span style=''>of</span> <span style=''>two</span> <span style=''>atoms</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>recent</span> <span style=''>methods</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transforming</span> <span style=''>texts</span> <span style=''>in</span> <span style=''>logic</span> <span style=''>formulas</span> <span style=''>Second</span> <span style=''>one</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.34453781512605036);'>relations</span> <span style=''>in</span> <span style=''>text</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3558052434456928);'>presented</span> <span style=''>in</span> <span style=''>WordNet</span> <span style=''>Some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarities</span> <span style=''>between</span> <span style=''>these</span> <span style=''>two</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>remarked</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Asymptotic</span> <span style=''>Behavior</span> <span style=''>of</span> <span style=''>Minimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exploration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Allocation</span> <span style=''>Policies</span> <span style=''>Almost</span> <span style=''>Sure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Arbitrarily</span> <span style=''>Slow</span> <span style=''>Growing</span> <span style=''>Regret</span> <br/><br/><span style=''>The</span> <span style=''>purpose</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>further</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>into</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>allocation</span> <span style=''>(stochastic</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>or</span> <span style=''>MAB)</span> <span style=''>problem</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establishing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>one</span> <span style=''>finite</span> <span style=''>horizon</span> <span style=''>bounds</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>rates</span> <span style=''>for</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>(or</span> <span style=''>pseudo)</span> <span style=''>regret</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>two</span> <span style=''>simple</span> <span style=''>classes</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>allocation</span> <span style=''>policies</span> <span style=''>pi</span> <span style=''>For</span> <span style=''>any</span> <span style=''>slowly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style=''>function</span> <span style=''>g</span> <span style=''>subject</span> <span style=''>to</span> <span style=''>mild</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>two</span> <span style=''>policies</span> <span style=''>(the</span> <span style=''>g</span> <span style=''>Forcing</span> <span style=''>and</span> <span style=''>the</span> <span style=''>g</span> <span style=''>Inflated</span> <span style=''>Sample</span> <span style=''>Mean)</span> <span style=''>that</span> <span style=''>achieve</span> <span style=''>a</span> <span style=''>measure</span> <span style=''>of</span> <span style=''>regret</span> <span style=''>of</span> <span style=''>order</span> <span style=''>O(g(n))</span> <span style=''>almost</span> <span style=''>surely</span> <span style=''>as</span> <span style=''>n</span> <span style=''>to</span> <span style=''>infty</span> <span style=''>bound</span> <span style=''>from</span> <span style=''>above</span> <span style=''>and</span> <span style=''>below</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Additionally</span> <span style=''>almost</span> <span style=''>sure</span> <span style=''>upper</span> <span style=''>and</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>remainder</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Pursuit</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>outlier</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>rejection</span> <span style=''>in</span> <span style=''>single</span> <span style=''>subspace</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>work</span> <span style=''>with</span> <span style=''>a</span> <span style=''>direct</span> <span style='background-color:rgba(0, 255, 0, 0.40560747663551416);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>subspace</span> <span style=''>and</span> <span style=''>are</span> <span style=''>thus</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>when</span> <span style=''>the</span> <span style=''>subspace</span> <span style='background-color:rgba(255, 0, 0, 0.3365384615384617);'>dimension</span> <span style=''>is</span> <span style=''>small</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>works</span> <span style=''>with</span> <span style=''>a</span> <span style=''>dual</span> <span style='background-color:rgba(0, 255, 0, 0.40560747663551416);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>subspace</span> <span style=''>and</span> <span style=''>hence</span> <span style=''>aims</span> <span style=''>to</span> <span style=''>find</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>orthogonal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complement</span> <span style=''>as</span> <span style=''>such</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style=''>suitable</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subspaces</span> <span style=''>whose</span> <span style='background-color:rgba(255, 0, 0, 0.3365384615384617);'>dimension</span> <span style=''>is</span> <span style=''>very</span> <span style=''>close</span> <span style=''>to</span> <span style=''>the</span> <span style=''>ambient</span> <span style='background-color:rgba(255, 0, 0, 0.3365384615384617);'>dimension</span> <span style=''>(subspaces</span> <span style=''>of</span> <span style=''>high</span> <span style=''>relative</span> <span style=''>dimension)</span> <span style=''>We</span> <span style=''>pose</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>normal</span> <span style=''>vectors</span> <span style=''>to</span> <span style=''>the</span> <span style=''>subspace</span> <span style=''>as</span> <span style=''>a</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>ell</span> <span style=''>1</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>problem</span> <span style=''>on</span> <span style=''>the</span> <span style=''>sphere</span> <span style=''>which</span> <span style=''>we</span> <span style=''>call</span> <span style=''>Dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Pursuit</span> <span style=''>(DPCP)</span> <span style=''>problem</span> <span style=''>We</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guar ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coherence</span> <span style=''>and</span> <span style=''>proper</span> <span style=''>scoring</span> <span style=''>rules</span> <br/><br/><span style=''>We</span> <span style=''>provide</span> <span style=''>self</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contained</span> <span style=''>proof</span> <span style=''>of</span> <span style=''>a</span> <span style=''>theorem</span> <span style=''>relating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coherence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasts</span> <span style=''>to</span> <span style=''>their</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>domination</span> <span style=''>by</span> <span style=''>rival</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasts</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>any</span> <span style=''>proper</span> <span style=''>scoring</span> <span style=''>rule</span> <span style=''>The</span> <span style=''>theorem</span> <span style=''>appears</span> <span style=''>to</span> <span style=''>be</span> <span style=''>new</span> <span style=''>but</span> <span style=''>is</span> <span style=''>closely</span> <span style=''>related</span> <span style=''>to</span> <span style=''>results</span> <span style=''>achieved</span> <span style=''>by</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigators</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.1072838177251525)
# 	segmentation (0.07176175098672408)
# 	representation (0.13491209185504127)
# 	detection (0.11661284535342663)
# 	architecture (0.09113742375313957)
# 	information (0.24363114459992824)
# 	experimental (0.1496232508073197)
# 	different (0.2691065662002153)
# 	convolutional (0.12988876928597057)
# 	recognition (0.13311804808037317)
#
# Some Statistics words are:
# 	algorithm (0.3914555389965226)
# 	theoretical (0.14505712866368603)
# 	stochastic (0.13611525086934922)
# 	variables (0.13561847988077497)
# 	distribution (0.17188276204669647)
# 	estimation (0.17784401390958768)
# 	statistical (0.15896671634376552)
# 	dimensional (0.18181818181818182)
# 	inference (0.19076005961251863)
# 	regression (0.17933432687531048)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4968d3e7-d1f4-4375-abdb-704ef4932327" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4968d3e7-d1f4-4375-abdb-704ef4932327")) {                    Plotly.newPlot(                        "4968d3e7-d1f4-4375-abdb-704ef4932327",                        [{"x":["approximation","scenarios","accomplished","benchmark","aggregate","configuration","representations","monitoring","consistent","generated","processing","discovery","algorithms","representation","detection","representing","archetypal","synthetic","estimation","algorithm","classification","parameterizations","formulation","illustrate","important","simultaneously","structure","estimating","constitutes","approximating","extension","transformed","expressive","empirical","demonstrate","information","trajectories","including","different","challenge","formulating","challenges","knowledge","correctness","collaborative","grounding","introduce","inferring","interactions","modalities","technical","associated","mechanisms","perception","performing","architecture","interpolation","euclidean","constrained","approaches","processes","transition","constructing","relationship","regression","simulation","illustrated","practically","covariance","manifolds","conditions","generality","potentially","utilities","computationally","intrinsic","irregular","accommodate","smoothing","distributed","attracted","identifies","attention","engineering","direction","electrical","countries","researchers","scientific","artificial","increasing","employing","stability","intelligence","comprehensive","electricity","providers","addressed","significant","reliability","predominant","ubiquitous","converting","corresponds","additional","conceptually","situation","discriminating","relevance","unlabeled","identified","automatically","supervised","retrieval","subsamples","applications","particular","transductive","inductive","empirically","simulated","available","classifier","recurrent","stabilisation","detecting","efficient","properties","stochastic","instability","signature","depressive","disability","prospective","technological","substantial","reporting","identification","combination","depression","performance","appropriate","consideration","intelligent","evaluating","comparison","probability","application","relational","structures","effective","magnitude","inference","reasoning","resulting","experiments","regarding","technique","compilation","questions","efficiently","techniques","compiling","backpropagation","competitive","decoupled","reasonably","optimizing","introduced","traditional","demonstrating","applicability","resolution","multilayer","equivalent","improvements","unsupervised","advantage","supervision","reproducing","prediction","convolutional","proposing","characterize","projections","maintains","differing","dimension","visualize","expression","dimensional","determined","exploited","determining","preserving","fluorescent","exploratory","relationships","selection","projection","malignant","performed","diagnosing","cytometry","individual","typically","clinicians","relatively","combinations","component","cytometric","procedure","boundaries","asymptotic","functional","leveraging","correlations","informative","evaluated","introduces","screening","marginally","multivariate","demonstrated","misclassification","ultrahigh","threshold","character","respectively","inconsistent","accuracies","utilizing","challenging","scheduling","constraints","continuous","programming","computing","integrates","literature","constraint","translate","represent","solutions","partially","bottleneck","switchboard","telephone","evaluation","recognition","sophisticated","conversational","beneficial","retraining","exponential","combining","rescoring","pu ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	stabilisation
# 	depressive
# 	prospective
# 	cytometric
# 	ultrahigh
# 	preselected
# 	overfitted
# 	quadrature
# 	breaching
# 	hypernetworks
# 	hypernetwork
# 	ellipsoids
# 	submodels
# 	uncountable
# 	shattering
# 	disaggregation
# 	renewable
# 	nesterovs
# 	stationarities
# 	textitfixed
# Some words which never appear in Statistics papers:
# 	grounding
# 	predominant
# 	compilation
# 	compiling
# 	switchboard
# 	telephone
# 	conversational
# 	rescoring
# 	proactive
# 	inconvenience
# 	occlusions
# 	mammography
# 	compositing
# 	googlenet
# 	daubechies
# 	surpassing
# 	articulated
# 	speculate
# 	mirroring
# 	destination

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.079860790292279e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.76
